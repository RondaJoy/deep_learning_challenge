# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns.
drop_columns = ['EIN', 'NAME', 'SPECIAL_CONSIDERATIONS', 'AFFILIATION', 'USE_CASE']
application_df = application_df.drop(drop_columns, 1)
application_df.head()
# Out:
# <ipython-input-2-54bb454ef614>:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   application_df = application_df.drop(drop_columns, 1)
#   APPLICATION_TYPE CLASSIFICATION  ORGANIZATION  STATUS     INCOME_AMT  \
# 0              T10          C1000   Association       1              0
# 1               T3          C2000  Co-operative       1         1-9999
# 2               T5          C3000   Association       1              0
# 3               T3          C2000         Trust       1    10000-24999
# 4               T3          C1000         Trust       1  100000-499999
#
#    ASK_AMT  IS_SUCCESSFUL
# 0     5000              1
# 1   108590              1
# 2     5000              0
# 3     6692              1
# 4   142590              1

# %%
# Choose a cutoff value and create a list of application types to be replaced.  Use the variable name `application_types_to_replace`.
application_types_to_replace = ['T9', 'T13', 'T12', 'T2', 'T25', 'T14', 'T29', 'T15', 'T17']

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced. Use the variable name `classifications_to_replace`.
classification_counts = application_df['CLASSIFICATION'].value_counts()
classifications_to_replace = classification_counts[classification_counts <1000].index.tolist()

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
application_encoded = pd.get_dummies(application_df)

# %%
# Split our preprocessed data into our features and target arrays
X = application_encoded.drop('IS_SUCCESSFUL', axis=1)
y = application_encoded['IS_SUCCESSFUL']

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
nfeatures = X_train.shape[1]
layer1 = 8
layer2 = 2
nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=layer1, input_dim=nfeatures, activation="relu"))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=layer2, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 8)                 248
#
#  dense_1 (Dense)             (None, 2)                 18
#
#  dense_2 (Dense)             (None, 1)                 3
#
# =================================================================
# Total params: 269 (1.05 KB)
# Trainable params: 269 (1.05 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
nn_trained = nn.fit(X_train_scaled,y_train,epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 4s 3ms/step - loss: 0.6671 - accuracy: 0.5952
# Epoch 2/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.6587 - accuracy: 0.6055
# Epoch 3/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.6558 - accuracy: 0.6105
# Epoch 4/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.6552 - accuracy: 0.6123
# Epoch 5/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6516 - accuracy: 0.6207
# Epoch 6/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6361 - accuracy: 0.6444
# Epoch 7/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6354 - accuracy: 0.6453
# Epoch 8/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6347 - accuracy: 0.6459
# Epoch 9/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6345 - accuracy: 0.6455
# Epoch 10/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6342 - accuracy: 0.6465
# Epoch 11/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6342 - accuracy: 0.6468
# Epoch 12/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6340 - accuracy: 0.6467
# Epoch 13/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6340 - accuracy: 0.6466
# Epoch 14/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6339 - accuracy: 0.6463
# Epoch 15/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6336 - accuracy: 0.6466
# Epoch 16/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6338 - accuracy: 0.6454
# Epoch 17/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6337 - accuracy: 0.6466
# Epoch 18/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6333 - accuracy: 0.6466
# Epoch 19/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6333 - accuracy: 0.6468
# Epoch 20/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6335 - accuracy: 0.6461
# Epoch 21/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6334 - accuracy: 0.6468
# Epoch 22/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6332 - accuracy: 0.6468
# Epoch 23/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6332 - accuracy: 0.6460
# Epoch 24/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6331 - accuracy: 0.6466
# Epoch 25/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6331 - accuracy: 0.6470
# Epoch 26/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6332 - accuracy: 0.6460
# Epoch 27/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6330 - accuracy: 0.6466
# Epoch 28/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6331 - accuracy: 0.6468
# Epoch 29/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6332 - accuracy: 0.6459
# Epoch 30/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6330 - accuracy: 0.6466
# Epoch 31/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6331 - accuracy: 0.6472
# Epoch 32/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6329 - accuracy: 0.6471
# Epoch 33/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6328 - accuracy: 0.6463
# Epoch 34/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6329 - accuracy: 0.6467
# Epoch 35/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6329 - accuracy: 0.6472
# Epoch 36/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6330 - accuracy: 0.6462
# Epoch 37/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6330 - accuracy: 0.6478
# Epoch 38/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6330 - accuracy: 0.6468
# Epoch 39/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6328 - accuracy: 0.6456
# Epoch 40/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6327 - accuracy: 0.6465
# Epoch 41/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6329 - accuracy: 0.6473
# Epoch 42/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6329 - accuracy: 0.6466
# Epoch 43/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6329 - accuracy: 0.6469
# Epoch 44/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6330 - accuracy: 0.6469
# Epoch 45/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6328 - accuracy: 0.6466
# Epoch 46/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6328 - accuracy: 0.6468
# Epoch 47/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6328 - accuracy: 0.6464
# Epoch 48/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6327 - accuracy: 0.6473
# Epoch 49/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6327 - accuracy: 0.6464
# Epoch 50/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6327 - accuracy: 0.6465
# Epoch 51/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6327 - accuracy: 0.6469
# Epoch 52/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6328 - accuracy: 0.6468
# Epoch 53/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.6328 - accuracy: 0.6468
# Epoch 54/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6327 - accuracy: 0.6462
# Epoch 55/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6325 - accuracy: 0.6465
# Epoch 56/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6325 - accuracy: 0.6470
# Epoch 57/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6326 - accuracy: 0.6464
# Epoch 58/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6325 - accuracy: 0.6469
# Epoch 59/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6324 - accuracy: 0.6468
# Epoch 60/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6325 - accuracy: 0.6468
# Epoch 61/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6322 - accuracy: 0.6466
# Epoch 62/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6323 - accuracy: 0.6462
# Epoch 63/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6322 - accuracy: 0.6465
# Epoch 64/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6325 - accuracy: 0.6461
# Epoch 65/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6323 - accuracy: 0.6471
# Epoch 66/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6324 - accuracy: 0.6473
# Epoch 67/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6322 - accuracy: 0.6473
# Epoch 68/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6324 - accuracy: 0.6471
# Epoch 69/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6323 - accuracy: 0.6473
# Epoch 70/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6322 - accuracy: 0.6469
# Epoch 71/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6321 - accuracy: 0.6473
# Epoch 72/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6323 - accuracy: 0.6472
# Epoch 73/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6324 - accuracy: 0.6469
# Epoch 74/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6322 - accuracy: 0.6467
# Epoch 75/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6323 - accuracy: 0.6471
# Epoch 76/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6322 - accuracy: 0.6471
# Epoch 77/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6323 - accuracy: 0.6461
# Epoch 78/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6322 - accuracy: 0.6471
# Epoch 79/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6324 - accuracy: 0.6468
# Epoch 80/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6322 - accuracy: 0.6469
# Epoch 81/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6323 - accuracy: 0.6474
# Epoch 82/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6321 - accuracy: 0.6460
# Epoch 83/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6321 - accuracy: 0.6474
# Epoch 84/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6322 - accuracy: 0.6478
# Epoch 85/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6322 - accuracy: 0.6470
# Epoch 86/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6322 - accuracy: 0.6467
# Epoch 87/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6322 - accuracy: 0.6469
# Epoch 88/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6323 - accuracy: 0.6460
# Epoch 89/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6321 - accuracy: 0.6477
# Epoch 90/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6322 - accuracy: 0.6461
# Epoch 91/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6322 - accuracy: 0.6459
# Epoch 92/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6322 - accuracy: 0.6476
# Epoch 93/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6321 - accuracy: 0.6479
# Epoch 94/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6322 - accuracy: 0.6470
# Epoch 95/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6321 - accuracy: 0.6475
# Epoch 96/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6322 - accuracy: 0.6474
# Epoch 97/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6321 - accuracy: 0.6473
# Epoch 98/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6323 - accuracy: 0.6474
# Epoch 99/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6322 - accuracy: 0.6472
# Epoch 100/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6320 - accuracy: 0.6471

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.6354 - accuracy: 0.6469 - 462ms/epoch - 2ms/step
# Loss: 0.6353870630264282, Accuracy: 0.6468804478645325

# %%
# Export your model to HDF5 file
nn.save("AlphabetSoupCharity_Optimization_01.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
