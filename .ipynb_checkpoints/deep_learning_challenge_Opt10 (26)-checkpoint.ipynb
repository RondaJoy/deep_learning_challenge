# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns.
drop_columns = ['EIN', 'NAME', 'SPECIAL_CONSIDERATIONS', 'AFFILIATION', 'USE_CASE']
application_df = application_df.drop(drop_columns, 1)
application_df.head()
# Out:
# <ipython-input-2-54bb454ef614>:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   application_df = application_df.drop(drop_columns, 1)
#   APPLICATION_TYPE CLASSIFICATION  ORGANIZATION  STATUS     INCOME_AMT  \
# 0              T10          C1000   Association       1              0
# 1               T3          C2000  Co-operative       1         1-9999
# 2               T5          C3000   Association       1              0
# 3               T3          C2000         Trust       1    10000-24999
# 4               T3          C1000         Trust       1  100000-499999
#
#    ASK_AMT  IS_SUCCESSFUL
# 0     5000              1
# 1   108590              1
# 2     5000              0
# 3     6692              1
# 4   142590              1

# %%
# Choose a cutoff value and create a list of application types to be replaced.  Use the variable name `application_types_to_replace`.
application_types_to_replace = ['T9', 'T13', 'T12', 'T2', 'T25', 'T14', 'T29', 'T15', 'T17']

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced. Use the variable name `classifications_to_replace`.
classification_counts = application_df['CLASSIFICATION'].value_counts()
classifications_to_replace = classification_counts[classification_counts <1000].index.tolist()

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
application_encoded = pd.get_dummies(application_df)

# %%
# Split our preprocessed data into our features and target arrays
X = application_encoded.drop('IS_SUCCESSFUL', axis=1)
y = application_encoded['IS_SUCCESSFUL']

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
nfeatures = X_train.shape[1]
layer1 = 8
layer2 = 2
nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=layer1, input_dim=nfeatures, activation="relu"))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=layer2, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 8)                 248
#
#  dense_1 (Dense)             (None, 2)                 18
#
#  dense_2 (Dense)             (None, 1)                 3
#
# =================================================================
# Total params: 269 (1.05 KB)
# Trainable params: 269 (1.05 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
nn_trained = nn.fit(X_train_scaled,y_train,epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 5s 4ms/step - loss: 0.6665 - accuracy: 0.6101
# Epoch 2/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.6407 - accuracy: 0.6415
# Epoch 3/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.6321 - accuracy: 0.6475
# Epoch 4/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.6279 - accuracy: 0.6485
# Epoch 5/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.6253 - accuracy: 0.6495
# Epoch 6/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.6231 - accuracy: 0.6495
# Epoch 7/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6214 - accuracy: 0.6493
# Epoch 8/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6203 - accuracy: 0.6506
# Epoch 9/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6191 - accuracy: 0.6518
# Epoch 10/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6182 - accuracy: 0.6520
# Epoch 11/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6178 - accuracy: 0.6520
# Epoch 12/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6172 - accuracy: 0.6518
# Epoch 13/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6165 - accuracy: 0.6514
# Epoch 14/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.6161 - accuracy: 0.6519
# Epoch 15/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6160 - accuracy: 0.6526
# Epoch 16/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6156 - accuracy: 0.6524
# Epoch 17/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6152 - accuracy: 0.6519
# Epoch 18/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6150 - accuracy: 0.6514
# Epoch 19/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6148 - accuracy: 0.6520
# Epoch 20/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6145 - accuracy: 0.6517
# Epoch 21/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6145 - accuracy: 0.6519
# Epoch 22/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.6142 - accuracy: 0.6515
# Epoch 23/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6139 - accuracy: 0.6524
# Epoch 24/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6139 - accuracy: 0.6519
# Epoch 25/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6138 - accuracy: 0.6523
# Epoch 26/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6136 - accuracy: 0.6520
# Epoch 27/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6135 - accuracy: 0.6533
# Epoch 28/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6133 - accuracy: 0.6525
# Epoch 29/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6132 - accuracy: 0.6525
# Epoch 30/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.6130 - accuracy: 0.6515
# Epoch 31/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6130 - accuracy: 0.6520
# Epoch 32/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6130 - accuracy: 0.6522
# Epoch 33/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6129 - accuracy: 0.6529
# Epoch 34/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6129 - accuracy: 0.6530
# Epoch 35/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6125 - accuracy: 0.6529
# Epoch 36/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6127 - accuracy: 0.6529
# Epoch 37/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6127 - accuracy: 0.6531
# Epoch 38/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.6127 - accuracy: 0.6537
# Epoch 39/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6124 - accuracy: 0.6527
# Epoch 40/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6123 - accuracy: 0.6530
# Epoch 41/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6123 - accuracy: 0.6510
# Epoch 42/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6124 - accuracy: 0.6528
# Epoch 43/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6122 - accuracy: 0.6530
# Epoch 44/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6122 - accuracy: 0.6527
# Epoch 45/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6120 - accuracy: 0.6536
# Epoch 46/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.6119 - accuracy: 0.6537
# Epoch 47/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6120 - accuracy: 0.6530
# Epoch 48/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6120 - accuracy: 0.6530
# Epoch 49/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6117 - accuracy: 0.6529
# Epoch 50/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6117 - accuracy: 0.6535
# Epoch 51/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6118 - accuracy: 0.6531
# Epoch 52/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6118 - accuracy: 0.6527
# Epoch 53/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6118 - accuracy: 0.6534
# Epoch 54/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.6117 - accuracy: 0.6530
# Epoch 55/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.6115 - accuracy: 0.6540
# Epoch 56/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.6114 - accuracy: 0.6536
# Epoch 57/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6116 - accuracy: 0.6531
# Epoch 58/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6113 - accuracy: 0.6539
# Epoch 59/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6114 - accuracy: 0.6528
# Epoch 60/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6116 - accuracy: 0.6531
# Epoch 61/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.6114 - accuracy: 0.6533
# Epoch 62/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6114 - accuracy: 0.6537
# Epoch 63/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6112 - accuracy: 0.6528
# Epoch 64/100
# 199/804 [======>.......................] - ETA: 1s - loss: 0.6139 - accuracy: 0.6427

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")

# %%
# Export your model to HDF5 file
nn.save("AlphabetSoupCharity_Optimization_01.h5")
